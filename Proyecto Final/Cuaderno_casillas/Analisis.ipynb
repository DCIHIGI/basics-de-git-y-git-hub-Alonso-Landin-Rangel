# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import math
import os
import glob
import pandas as pd
import re

# %%
files = glob.glob("*.txt")

# %%
data_1 = pd.read_csv(files[0], usecols = [0,1,2,13])

# %%
data_1_GTO = data_1[data_1["ENTIDAD"] == 11]

# %%
mun = np.unique (data_1_GTO['MUNICIPIO'])

# %%
lista_mun = []
for i in mun:
   lista_mun.append(data_1_GTO[data_1_GTO['MUNICIPIO']==i]['LISTA_NACIONAL'].sum())

# %%
pd.DataFrame({'MUNICIPIO':mun[1:],'LISTA_202001':lista_mun[1:]})
# Out:
#     MUNICIPIO  LISTA_202001
# 0           1         65505
# 1           2         91712
# 2           3        125884
# 3           4         48907
# 4           5         66789
# 5           6          4145
# 6           7        370594
# 7           8         30822
# 8           9         58753
# 9          10          9192
# 10         11         72878
# 11         12         22885
# 12         13         17908
# 13         14        111422
# 14         15        136661
# 15         16         16529
# 16         17        415817
# 17         18         28508
# 18         19         40282
# 19         20       1119434
# 20         21         42421
# 21         22         17639
# 22         23        122145
# 23         24         10548
# 24         25         54050
# 25         26         44971
# 26         27        207757
# 27         28         81821
# 28         29         27253
# 29         30         80311
# 30         31         90803
# 31         32         58512
# ...

# %%
lista_nal_mun = data_1_GTO[1:].groupby(['MUNICIPIO']).sum()['LISTA_NACIONAL']

# %%
LISTA_NACIONAL_MUN = pd.DataFrame(lista_nal_mun)

# %%
LISTA_NACIONAL_MUN
# Out:
#            LISTA_NACIONAL
# MUNICIPIO
# 1                   65505
# 2                   91712
# 3                  125884
# 4                   48907
# 5                   66789
# 6                    4145
# 7                  370594
# 8                   30822
# 9                   58753
# 10                   9192
# 11                  72878
# 12                  22885
# 13                  17908
# 14                 111422
# 15                 136661
# 16                  16529
# 17                 415817
# 18                  28508
# 19                  40282
# 20                1119434
# 21                  42421
# 22                  17639
# 23                 122145
# 24                  10548
# 25                  54050
# 26                  44971
# 27                 207757
# 28                  81821
# 29                  27253
# 30                  80311
# 31                  90803
# 32                  58512
# 33                  88735
# 34                   4342
# ...

# %%
date=[]
date_=[]
files_=[]

for i,file in enumerate(files):
    date.append(re.findall(r'\d+',file)[0])


temp=sorted(range(len(date)), key=date.__getitem__)

for i in temp:
    date_.append(date[i])
    print(date[i],files[i])
    files_.append(files[i])
# Out:
# 20200131 20200131.txt
# 20200229 20200229.txt
# 20200331 20200331.txt
# 20200430 20200430.txt
# 20200531 20200531.txt
# 20200630 20200630.txt
# 20200731 20200731.txt
# 20200831 20200831.txt
# 20200930 20200930.txt
# 20201031 20201031.txt
# 20201130 20201130.txt
# 20201231 20201231.txt

# %%
for i,file in enumerate(files_):
    data=pd.read_csv(file , usecols = [0,1,2,13])
    data=data[1:]
    data=data[data['ENTIDAD']==11][1:]
    mpo=data.groupby(['MUNICIPIO']).sum()
    if i==0 :
        if 'LISTA_NAL' in mpo.columns:
            df_mpo = pd.DataFrame(mpo['LISTA_NAL'])
        if 'LISTA_NACIONAL' in mpo.columns:
            df_mpo = pd.DataFrame(mpo['LISTA_NACIONAL'])
        if 'LISTA' in mpo.columns:
            df_mpo = pd.DataFrame(mpo['LISTA'])
    else:
        if 'LISTA_NAL' in mpo.columns:
            df_mpo[date_[i]]=mpo['LISTA_NAL']
        if 'LISTA_NACIONAL' in mpo.columns:
            df_mpo[date_[i]]=mpo['LISTA_NACIONAL']
        if 'LISTA' in mpo.columns:
            df_mpo[date_[i]]=mpo['LISTA']

# %%
municipios=np.asarray(df_mpo)

# %%
fits=[]
prediction_lnal=[]

for i in range(len(municipios)):
    xx=np.arange(len(municipios[i]))
    ma, ba = np. polyfit(xx, municipios[i],1,w=municipios[i])
    fits.append([ma,ba])
    pred=ma*(13)+ba
    prediction_lnal.append(pred)

# %%
df_mpo['Prediction LNAL']=prediction_lnal

# %%
df_mpo
# Out:
#            LISTA_NACIONAL  20200229  20200331   20200430  20200531  20200630  \
# MUNICIPIO
# 1                   65505     66245     66750    66736.0     68057     68054
# 2                   91712     92759     93343    93340.0     94967     94967
# 3                  125884    127461    128544   128543.0    130720    130717
# 4                   48907     49311     49596    49596.0     50283     50281
# 5                   66789     67553     68063    68058.0     69125     69124
# 6                    4145      4162      4212     4212.0      4244      4244
# 7                  370594    374915    378228   378153.0    383007    383002
# 8                   30822     31080     31406    31385.0     31800     31799
# 9                   58753     59504     59917    59910.0     60931     60931
# 10                   9192      9256      9279     9278.0      9376      9376
# 11                  72878     73771     74222    74218.0     75392     75392
# ...

# %%
ene_2020 = []
ene_2020=df_mpo['LISTA_NACIONAL'].values

# %%
crec = []
for i in range(len(municipios)):
    crecim = prediction_lnal[i] / ene_2020[i]
    crec.append(crecim)

# %%
df_mpo['Factor de crecimiento']=crec

# %%
df_mpo
# Out:
#            LISTA_NACIONAL  20200229  20200331   20200430  20200531  20200630  \
# MUNICIPIO
# 1                   65505     66245     66750    66736.0     68057     68054
# 2                   91712     92759     93343    93340.0     94967     94967
# 3                  125884    127461    128544   128543.0    130720    130717
# 4                   48907     49311     49596    49596.0     50283     50281
# 5                   66789     67553     68063    68058.0     69125     69124
# 6                    4145      4162      4212     4212.0      4244      4244
# 7                  370594    374915    378228   378153.0    383007    383002
# 8                   30822     31080     31406    31385.0     31800     31799
# 9                   58753     59504     59917    59910.0     60931     60931
# 10                   9192      9256      9279     9278.0      9376      9376
# 11                  72878     73771     74222    74218.0     75392     75392
# ...

# %%
data_sec = pd.read_csv(files[0], usecols = [0,1,2,3,13])

# %%
data_sec = data_sec[data_sec["ENTIDAD"] == 11][1:]

# %%
data_mun1 = data_sec[data_sec["MUNICIPIO"] == 1]['LISTA_NACIONAL'].values
data_mun2 = data_sec[data_sec["MUNICIPIO"] == 2]['LISTA_NACIONAL'].values
data_mun3 = data_sec[data_sec["MUNICIPIO"] == 3]['LISTA_NACIONAL'].values
data_mun4 = data_sec[data_sec["MUNICIPIO"] == 4]['LISTA_NACIONAL'].values
data_mun5 = data_sec[data_sec["MUNICIPIO"] == 5]['LISTA_NACIONAL'].values
data_mun6 = data_sec[data_sec["MUNICIPIO"] == 6]['LISTA_NACIONAL'].values
data_mun7 = data_sec[data_sec["MUNICIPIO"] == 7]['LISTA_NACIONAL'].values
data_mun8 = data_sec[data_sec["MUNICIPIO"] == 8]['LISTA_NACIONAL'].values
data_mun9 = data_sec[data_sec["MUNICIPIO"] == 9]['LISTA_NACIONAL'].values
data_mun10 = data_sec[data_sec["MUNICIPIO"] == 10]['LISTA_NACIONAL'].values
data_mun11 = data_sec[data_sec["MUNICIPIO"] == 11]['LISTA_NACIONAL'].values
data_mun12 = data_sec[data_sec["MUNICIPIO"] == 12]['LISTA_NACIONAL'].values
data_mun13 = data_sec[data_sec["MUNICIPIO"] == 13]['LISTA_NACIONAL'].values
data_mun14 = data_sec[data_sec["MUNICIPIO"] == 14]['LISTA_NACIONAL'].values
data_mun15 = data_sec[data_sec["MUNICIPIO"] == 15]['LISTA_NACIONAL'].values
data_mun16 = data_sec[data_sec["MUNICIPIO"] == 16]['LISTA_NACIONAL'].values
data_mun17 = data_sec[data_sec["MUNICIPIO"] == 17]['LISTA_NACIONAL'].values
data_mun18 = data_sec[data_sec["MUNICIPIO"] == 18]['LISTA_NACIONAL'].values
data_mun19 = data_sec[data_sec["MUNICIPIO"] == 19]['LISTA_NACIONAL'].values
data_mun20 = data_sec[data_sec["MUNICIPIO"] == 20]['LISTA_NACIONAL'].values
data_mun21 = data_sec[data_sec["MUNICIPIO"] == 21]['LISTA_NACIONAL'].values
data_mun22 = data_sec[data_sec["MUNICIPIO"] == 22]['LISTA_NACIONAL'].values
data_mun23 = data_sec[data_sec["MUNICIPIO"] == 23]['LISTA_NACIONAL'].values
data_mun24 = data_sec[data_sec["MUNICIPIO"] == 24]['LISTA_NACIONAL'].values
data_mun25 = data_sec[data_sec["MUNICIPIO"] == 25]['LISTA_NACIONAL'].values
data_mun26 = data_sec[data_sec["MUNICIPIO"] == 26]['LISTA_NACIONAL'].values
data_mun27 = data_sec[data_sec["MUNICIPIO"] == 27]['LISTA_NACIONAL'].values
data_mun28 = data_sec[data_sec["MUNICIPIO"] == 28]['LISTA_NACIONAL'].values
data_mun29 = data_sec[data_sec["MUNICIPIO"] == 29]['LISTA_NACIONAL'].values
data_mun30 = data_sec[data_sec["MUNICIPIO"] == 30]['LISTA_NACIONAL'].values
data_mun31 = data_sec[data_sec["MUNICIPIO"] == 31]['LISTA_NACIONAL'].values
data_mun32 = data_sec[data_sec["MUNICIPIO"] == 32]['LISTA_NACIONAL'].values
data_mun33 = data_sec[data_sec["MUNICIPIO"] == 33]['LISTA_NACIONAL'].values
data_mun34 = data_sec[data_sec["MUNICIPIO"] == 34]['LISTA_NACIONAL'].values
data_mun35 = data_sec[data_sec["MUNICIPIO"] == 35]['LISTA_NACIONAL'].values
data_mun36 = data_sec[data_sec["MUNICIPIO"] == 36]['LISTA_NACIONAL'].values
data_mun37 = data_sec[data_sec["MUNICIPIO"] == 37]['LISTA_NACIONAL'].values
data_mun38 = data_sec[data_sec["MUNICIPIO"] == 38]['LISTA_NACIONAL'].values
data_mun39 = data_sec[data_sec["MUNICIPIO"] == 39]['LISTA_NACIONAL'].values
data_mun40 = data_sec[data_sec["MUNICIPIO"] == 40]['LISTA_NACIONAL'].values
data_mun41 = data_sec[data_sec["MUNICIPIO"] == 41]['LISTA_NACIONAL'].values
data_mun42 = data_sec[data_sec["MUNICIPIO"] == 42]['LISTA_NACIONAL'].values
data_mun43 = data_sec[data_sec["MUNICIPIO"] == 43]['LISTA_NACIONAL'].values
data_mun44 = data_sec[data_sec["MUNICIPIO"] == 44]['LISTA_NACIONAL'].values
data_mun45 = data_sec[data_sec["MUNICIPIO"] == 45]['LISTA_NACIONAL'].values
data_mun46 = data_sec[data_sec["MUNICIPIO"] == 46]['LISTA_NACIONAL'].values

# %%
for i in range(len(data_mun1)):
    data_mun1[i]=crec[0]*data_mun1[i]
for i in range(len(data_mun2)):
    data_mun2[i]=crec[1]*data_mun2[i]
for i in range(len(data_mun3)):
    data_mun3[i]=crec[2]*data_mun3[i]
for i in range(len(data_mun4)):
    data_mun4[i]=crec[3]*data_mun4[i]
for i in range(len(data_mun5)):
    data_mun5[i]=crec[4]*data_mun5[i]
for i in range(len(data_mun6)):
    data_mun6[i]=crec[5]*data_mun6[i]
for i in range(len(data_mun7)):
    data_mun7[i]=crec[6]*data_mun7[i]
for i in range(len(data_mun8)):
    data_mun8[i]=crec[7]*data_mun8[i]
for i in range(len(data_mun9)):
    data_mun9[i]=crec[8]*data_mun9[i]
for i in range(len(data_mun10)):
    data_mun10[i]=crec[9]*data_mun10[i]
for i in range(len(data_mun11)):
    data_mun11[i]=crec[10]*data_mun11[i]
for i in range(len(data_mun12)):
    data_mun12[i]=crec[11]*data_mun12[i]
for i in range(len(data_mun13)):
    data_mun13[i]=crec[12]*data_mun13[i]
for i in range(len(data_mun14)):
    data_mun14[i]=crec[13]*data_mun14[i]
for i in range(len(data_mun15)):
    data_mun15[i]=crec[14]*data_mun15[i]
for i in range(len(data_mun16)):
    data_mun16[i]=crec[15]*data_mun16[i]
for i in range(len(data_mun17)):
    data_mun17[i]=crec[16]*data_mun17[i]
for i in range(len(data_mun18)):
    data_mun18[i]=crec[17]*data_mun18[i]
for i in range(len(data_mun19)):
    data_mun19[i]=crec[18]*data_mun19[i]
for i in range(len(data_mun20)):
    data_mun20[i]=crec[19]*data_mun20[i]
for i in range(len(data_mun21)):
    data_mun21[i]=crec[20]*data_mun21[i]
for i in range(len(data_mun22)):
    data_mun22[i]=crec[21]*data_mun22[i]
for i in range(len(data_mun23)):
    data_mun23[i]=crec[22]*data_mun23[i]
for i in range(len(data_mun24)):
    data_mun24[i]=crec[23]*data_mun24[i]
for i in range(len(data_mun25)):
    data_mun25[i]=crec[24]*data_mun25[i]
for i in range(len(data_mun26)):
    data_mun26[i]=crec[25]*data_mun26[i]
for i in range(len(data_mun27)):
    data_mun27[i]=crec[26]*data_mun27[i]
for i in range(len(data_mun28)):
    data_mun28[i]=crec[27]*data_mun28[i]
for i in range(len(data_mun29)):
    data_mun29[i]=crec[28]*data_mun29[i]
for i in range(len(data_mun30)):
    data_mun30[i]=crec[29]*data_mun30[i]
for i in range(len(data_mun31)):
    data_mun31[i]=crec[30]*data_mun31[i]
for i in range(len(data_mun32)):
    data_mun32[i]=crec[31]*data_mun32[i]
for i in range(len(data_mun33)):
    data_mun33[i]=crec[32]*data_mun33[i]
for i in range(len(data_mun34)):
    data_mun34[i]=crec[33]*data_mun34[i]
for i in range(len(data_mun35)):
    data_mun35[i]=crec[34]*data_mun35[i]
for i in range(len(data_mun36)):
    data_mun36[i]=crec[35]*data_mun36[i]
for i in range(len(data_mun37)):
    data_mun37[i]=crec[36]*data_mun37[i]
for i in range(len(data_mun38)):
    data_mun38[i]=crec[37]*data_mun38[i]
for i in range(len(data_mun39)):
    data_mun39[i]=crec[38]*data_mun39[i]
for i in range(len(data_mun40)):
    data_mun40[i]=crec[39]*data_mun40[i]
for i in range(len(data_mun41)):
    data_mun41[i]=crec[40]*data_mun41[i]
for i in range(len(data_mun42)):
    data_mun42[i]=crec[41]*data_mun42[i]
for i in range(len(data_mun43)):
    data_mun43[i]=crec[42]*data_mun43[i]
for i in range(len(data_mun44)):
    data_mun44[i]=crec[43]*data_mun44[i]
for i in range(len(data_mun45)):
    data_mun45[i]=crec[44]*data_mun45[i]
for i in range(len(data_mun46)):
    data_mun46[i]=crec[45]*data_mun46[i]

# %%
casillas_1 = []
casillas_2 = []
casillas_3 = []
casillas_4 = []
casillas_5 = []
casillas_6 = []
casillas_7 = []
casillas_8 = []
casillas_9 = []
casillas_10 = []
casillas_11 = []
casillas_12 = []
casillas_13 = []
casillas_14 = []
casillas_15 = []
casillas_16 = []
casillas_17 = []
casillas_18 = []
casillas_19 = []
casillas_20 = []
casillas_21 = []
casillas_22 = []
casillas_23 = []
casillas_24 = []
casillas_25 = []
casillas_26 = []
casillas_27 = []
casillas_28 = []
casillas_29 = []
casillas_30 = []
casillas_31 = []
casillas_32 = []
casillas_33 = []
casillas_34 = []
casillas_35 = []
casillas_36 = []
casillas_37 = []
casillas_38 = []
casillas_39 = []
casillas_40 = []
casillas_41 = []
casillas_42 = []
casillas_43 = []
casillas_44 = []
casillas_45 = []
casillas_46 = []

# %%
for i in range(len(data_mun1)):
    casillas = math.ceil(data_mun1[i] / 750)
    casillas_1.append(casillas)
for i in range(len(data_mun2)):
    casillas = math.ceil(data_mun2[i] / 750)
    casillas_2.append(casillas)
for i in range(len(data_mun3)):
    casillas = math.ceil(data_mun3[i] / 750)
    casillas_3.append(casillas)
for i in range(len(data_mun4)):
    casillas = math.ceil(data_mun4[i] / 750)
    casillas_4.append(casillas)
for i in range(len(data_mun5)):
    casillas = math.ceil(data_mun5[i] / 750)
    casillas_5.append(casillas)
for i in range(len(data_mun6)):
    casillas = math.ceil(data_mun6[i] / 750)
    casillas_6.append(casillas)
for i in range(len(data_mun7)):
    casillas = math.ceil(data_mun7[i] / 750)
    casillas_7.append(casillas)
for i in range(len(data_mun8)):
    casillas = math.ceil(data_mun8[i] / 750)
    casillas_8.append(casillas)
for i in range(len(data_mun9)):
    casillas = math.ceil(data_mun9[i] / 750)
    casillas_9.append(casillas)
for i in range(len(data_mun10)):
    casillas = math.ceil(data_mun10[i] / 750)
    casillas_10.append(casillas)
for i in range(len(data_mun11)):
    casillas = math.ceil(data_mun11[i] / 750)
    casillas_11.append(casillas)
for i in range(len(data_mun12)):
    casillas = math.ceil(data_mun12[i] / 750)
    casillas_12.append(casillas)
for i in range(len(data_mun13)):
    casillas = math.ceil(data_mun13[i] / 750)
    casillas_13.append(casillas)
for i in range(len(data_mun14)):
    casillas = math.ceil(data_mun14[i] / 750)
    casillas_14.append(casillas)
for i in range(len(data_mun15)):
    casillas = math.ceil(data_mun15[i] / 750)
    casillas_15.append(casillas)
for i in range(len(data_mun16)):
    casillas = math.ceil(data_mun16[i] / 750)
    casillas_16.append(casillas)
for i in range(len(data_mun17)):
    casillas = math.ceil(data_mun17[i] / 750)
    casillas_17.append(casillas)
for i in range(len(data_mun18)):
    casillas = math.ceil(data_mun18[i] / 750)
    casillas_18.append(casillas)
for i in range(len(data_mun19)):
    casillas = math.ceil(data_mun19[i] / 750)
    casillas_19.append(casillas)
for i in range(len(data_mun20)):
    casillas = math.ceil(data_mun20[i] / 750)
    casillas_20.append(casillas)
for i in range(len(data_mun21)):
    casillas = math.ceil(data_mun21[i] / 750)
    casillas_21.append(casillas)
for i in range(len(data_mun22)):
    casillas = math.ceil(data_mun22[i] / 750)
    casillas_22.append(casillas)
for i in range(len(data_mun23)):
    casillas = math.ceil(data_mun23[i] / 750)
    casillas_23.append(casillas)
for i in range(len(data_mun24)):
    casillas = math.ceil(data_mun24[i] / 750)
    casillas_24.append(casillas)
for i in range(len(data_mun25)):
    casillas = math.ceil(data_mun25[i] / 750)
    casillas_25.append(casillas)
for i in range(len(data_mun26)):
    casillas = math.ceil(data_mun26[i] / 750)
    casillas_26.append(casillas)
for i in range(len(data_mun27)):
    casillas = math.ceil(data_mun27[i] / 750)
    casillas_27.append(casillas)
for i in range(len(data_mun28)):
    casillas = math.ceil(data_mun28[i] / 750)
    casillas_28.append(casillas)
for i in range(len(data_mun29)):
    casillas = math.ceil(data_mun29[i] / 750)
    casillas_29.append(casillas)
for i in range(len(data_mun30)):
    casillas = math.ceil(data_mun30[i] / 750)
    casillas_30.append(casillas)
for i in range(len(data_mun31)):
    casillas = math.ceil(data_mun31[i] / 750)
    casillas_31.append(casillas)
for i in range(len(data_mun32)):
    casillas = math.ceil(data_mun32[i] / 750)
    casillas_32.append(casillas)
for i in range(len(data_mun33)):
    casillas = math.ceil(data_mun33[i] / 750)
    casillas_33.append(casillas)
for i in range(len(data_mun34)):
    casillas = math.ceil(data_mun34[i] / 750)
    casillas_34.append(casillas)
for i in range(len(data_mun35)):
    casillas = math.ceil(data_mun35[i] / 750)
    casillas_35.append(casillas)
for i in range(len(data_mun36)):
    casillas = math.ceil(data_mun36[i] / 750)
    casillas_36.append(casillas)
for i in range(len(data_mun37)):
    casillas = math.ceil(data_mun37[i] / 750)
    casillas_37.append(casillas)
for i in range(len(data_mun38)):
    casillas = math.ceil(data_mun38[i] / 750)
    casillas_38.append(casillas)
for i in range(len(data_mun39)):
    casillas = math.ceil(data_mun39[i] / 750)
    casillas_39.append(casillas)
for i in range(len(data_mun40)):
    casillas = math.ceil(data_mun40[i] / 750)
    casillas_40.append(casillas)
for i in range(len(data_mun41)):
    casillas = math.ceil(data_mun41[i] / 750)
    casillas_41.append(casillas)
for i in range(len(data_mun42)):
    casillas = math.ceil(data_mun42[i] / 750)
    casillas_42.append(casillas)
for i in range(len(data_mun43)):
    casillas = math.ceil(data_mun43[i] / 750)
    casillas_43.append(casillas)
for i in range(len(data_mun44)):
    casillas = math.ceil(data_mun44[i] / 750)
    casillas_44.append(casillas)
for i in range(len(data_mun45)):
    casillas = math.ceil(data_mun45[i] / 750)
    casillas_45.append(casillas)
for i in range(len(data_mun46)):
    casillas = math.ceil(data_mun46[i] / 750)
    casillas_46.append(casillas)

# %%
cas_proy_1 = sum(casillas_1)
cas_proy_2 = sum(casillas_2)
cas_proy_3 = sum(casillas_3)
cas_proy_4 = sum(casillas_4)
cas_proy_5 = sum(casillas_5)
cas_proy_6 = sum(casillas_6)
cas_proy_7 = sum(casillas_7)
cas_proy_8 = sum(casillas_8)
cas_proy_9 = sum(casillas_9)
cas_proy_10 = sum(casillas_10)
cas_proy_11 = sum(casillas_11)
cas_proy_12 = sum(casillas_12)
cas_proy_13 = sum(casillas_13)
cas_proy_14 = sum(casillas_14)
cas_proy_15 = sum(casillas_15)
cas_proy_16 = sum(casillas_16)
cas_proy_17 = sum(casillas_17)
cas_proy_18 = sum(casillas_18)
cas_proy_19 = sum(casillas_19)
cas_proy_20 = sum(casillas_20)
cas_proy_21 = sum(casillas_21)
cas_proy_22 = sum(casillas_22)
cas_proy_23 = sum(casillas_23)
cas_proy_24 = sum(casillas_24)
cas_proy_25 = sum(casillas_25)
cas_proy_26 = sum(casillas_26)
cas_proy_27 = sum(casillas_27)
cas_proy_28 = sum(casillas_28)
cas_proy_29 = sum(casillas_29)
cas_proy_30 = sum(casillas_30)
cas_proy_31 = sum(casillas_31)
cas_proy_32 = sum(casillas_32)
cas_proy_33 = sum(casillas_33)
cas_proy_34 = sum(casillas_34)
cas_proy_35 = sum(casillas_35)
cas_proy_36 = sum(casillas_36)
cas_proy_37 = sum(casillas_37)
cas_proy_38 = sum(casillas_38)
cas_proy_39 = sum(casillas_39)
cas_proy_40 = sum(casillas_40)
cas_proy_41 = sum(casillas_41)
cas_proy_42 = sum(casillas_42)
cas_proy_43 = sum(casillas_43)
cas_proy_44 = sum(casillas_44)
cas_proy_45 = sum(casillas_45)
cas_proy_46 = sum(casillas_46)

# %%
mun = mun[1:]

# %%
cas_proy = []
cas_proy.append(cas_proy_1)
cas_proy.append(cas_proy_2)
cas_proy.append(cas_proy_3)
cas_proy.append(cas_proy_4)
cas_proy.append(cas_proy_5)
cas_proy.append(cas_proy_6)
cas_proy.append(cas_proy_7)
cas_proy.append(cas_proy_8)
cas_proy.append(cas_proy_9)
cas_proy.append(cas_proy_10)
cas_proy.append(cas_proy_11)
cas_proy.append(cas_proy_12)
cas_proy.append(cas_proy_13)
cas_proy.append(cas_proy_14)
cas_proy.append(cas_proy_15)
cas_proy.append(cas_proy_16)
cas_proy.append(cas_proy_17)
cas_proy.append(cas_proy_18)
cas_proy.append(cas_proy_19)
cas_proy.append(cas_proy_20)
cas_proy.append(cas_proy_21)
cas_proy.append(cas_proy_22)
cas_proy.append(cas_proy_23)
cas_proy.append(cas_proy_24)
cas_proy.append(cas_proy_25)
cas_proy.append(cas_proy_26)
cas_proy.append(cas_proy_27)
cas_proy.append(cas_proy_28)
cas_proy.append(cas_proy_29)
cas_proy.append(cas_proy_30)
cas_proy.append(cas_proy_31)
cas_proy.append(cas_proy_32)
cas_proy.append(cas_proy_33)
cas_proy.append(cas_proy_34)
cas_proy.append(cas_proy_35)
cas_proy.append(cas_proy_36)
cas_proy.append(cas_proy_37)
cas_proy.append(cas_proy_38)
cas_proy.append(cas_proy_39)
cas_proy.append(cas_proy_40)
cas_proy.append(cas_proy_41)
cas_proy.append(cas_proy_42)
cas_proy.append(cas_proy_43)
cas_proy.append(cas_proy_44)
cas_proy.append(cas_proy_45)
cas_proy.append(cas_proy_46)

# %%
df_final = pd.DataFrame(list(zip(mun,cas_proy)) , columns=['Municipio','Casillas requeridas'])

# %%
df_final
# Out:
#     Municipio  Casillas requeridas
# 0           1                  234
# 1           2                  175
# 2           3                  227
# 3           4                   92
# 4           5                  115
# 5           6                    8
# 6           7                  646
# 7           8                   65
# 8           9                  105
# 9          10                   18
# 10         11                  131
# 11         12                   43
# 12         13                   32
# 13         14                  190
# 14         15                  238
# 15         16                   30
# 16         17                  707
# 17         18                   51
# 18         19                   82
# 19         20                 1921
# 20         21                   77
# 21         22                   36
# 22         23                  232
# 23         24                   19
# 24         25                   89
# 25         26                   88
# ...

# %%
df_list_nom_pro = pd.DataFrame(list(zip(mun,prediction_lnal)) , columns=['Municipio','Lista proyectada'])

# %%
df_list_nom_pro
# Out:
#     Municipio  Lista proyectada
# 0           1      6.945182e+04
# 1           2      9.711037e+04
# 2           3      1.346175e+05
# 3           4      5.132333e+04
# 4           5      7.089104e+04
# 5           6      4.296146e+03
# 6           7      3.912036e+05
# 7           8      3.272813e+04
# 8           9      6.252809e+04
# 9          10      9.487137e+03
# 10         11      7.652699e+04
# 11         12      2.399836e+04
# 12         13      1.899644e+04
# 13         14      1.176435e+05
# 14         15      1.448553e+05
# 15         16      1.711581e+04
# 16         17      4.391221e+05
# 17         18      2.990586e+04
# 18         19      4.204856e+04
# 19         20      1.182018e+06
# 20         21      4.478995e+04
# 21         22      1.872755e+04
# 22         23      1.292109e+05
# 23         24      1.103358e+04
# 24         25      5.764103e+04
# 25         26      4.745201e+04
# 26         27      2.198656e+05
# 27         28      8.500817e+04
# ...
